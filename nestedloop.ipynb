# %%
#nestdloop
for i in range (1,6):
    for j in range (1,11):
        print(i,"x",j,"=",i*j)
        print("-"*15)
# Out:
# 1 x 1 = 1
# ---------------
# 1 x 2 = 2
# ---------------
# 1 x 3 = 3
# ---------------
# 1 x 4 = 4
# ---------------
# 1 x 5 = 5
# ---------------
# 1 x 6 = 6
# ---------------
# 1 x 7 = 7
# ---------------
# 1 x 8 = 8
# ---------------
# 1 x 9 = 9
# ---------------
# 1 x 10 = 10
# ---------------
# 2 x 1 = 2
# ---------------
# 2 x 2 = 4
# ---------------
# 2 x 3 = 6
# ---------------
# 2 x 4 = 8
# ---------------
# 2 x 5 = 10
# ---------------
# 2 x 6 = 12
# ---------------
# 2 x 7 = 14
# ---------------
# 2 x 8 = 16
# ---------------
# 2 x 9 = 18
# ---------------
# 2 x 10 = 20
# ---------------
# 3 x 1 = 3
# ---------------
# 3 x 2 = 6
# ---------------
# 3 x 3 = 9
# ---------------
# 3 x 4 = 12
# ---------------
# 3 x 5 = 15
# ---------------
# 3 x 6 = 18
# ---------------
# 3 x 7 = 21
# ---------------
# 3 x 8 = 24
# ---------------
# 3 x 9 = 27
# ---------------
# 3 x 10 = 30
# ---------------
# 4 x 1 = 4
# ---------------
# 4 x 2 = 8
# ---------------
# 4 x 3 = 12
# ...
