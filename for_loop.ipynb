# %%
# for loop to print 1 to 10 number
''''for i in range(1,10):
    print(i)

# odd number
for i in range(1,19,2):
   print(i)

# using list or string
fruits=["apple", "mango", "banana"]
for fruit in fruits:
            print(fruit)
'''
#looking through string
name="jayprakash"
for char in name:
     print(char)
# Out:
# j
# a
# y
# p
# r
# a
# k
# a
# s
# h
