# %%
#1. python if condition
a=10
b=20
print(" The value of a & b is :", a,b)
if b>a:
    print("b is greatr than a")

#1.1 if else condition
age = int(input("enter your age"))
if (age>=18):
     print("you are eligible")  
else:
     print("you are not eligible")
# Out:
#  The value of a & b is : 10 20
# b is greatr than a
# enter your age 18
# you are eligible
